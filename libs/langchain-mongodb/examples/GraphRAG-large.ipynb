# %% [markdown]
# # Large-Scale Knowledge Graph Construction and Visualization
#
# This notebook demonstrates building a substantial knowledge graph from a text corpus containing approximately 100 entities.
#
# We will:
# 1. Load a large text dataset about technology companies, people, and projects
# 2. Chunk the text into paragraph-sized documents using `RecursiveCharacterTextSplitter`
# 3. Extract entities and relationships using `MongoDBGraphStore`
# 4. Visualize the resulting knowledge graph using HoloViews and NetworkX
#
# The dataset contains news-style articles about:
# - Organizations (tech companies, research institutions, nonprofits)
# - People (CEOs, scientists, directors)
# - Projects and initiatives
# - Locations and facilities
# - Technologies and products

# %%
import os
from pathlib import Path

import holoviews as hv
import networkx as nx
from holoviews import opts
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_mongodb.graphrag.graph import MongoDBGraphStore

# %%
hv.extension("bokeh")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='730f3d7d-796c-4947-9c58-860e15985a19'>
#   <div id="d6abacaa-bd2a-441f-8380-72fabb18d7bf" data-root-id="730f3d7d-796c-4947-9c58-860e15985a19" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"95c15ce8-c450-48a3-9d4d-34c884ac8f27":{"version":"3.8.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"a46e9176-42fa-44fd-8248-db3b5c3e1fb4","attributes":{"notifications":{"type":"object","name":"Notifications","id":"52b7664d-ab09-48ac-9979-0a6bb54c5ccc"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"730f3d7d-796c-4947-9c58-860e15985a19"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"838fae79-301a-4d43-9108-a6ff8b09910d","attributes":{"plot_id":"730f3d7d-796c-4947-9c58-860e15985a19","comm_id":"d3309976ba434c24b09bcd40a476f2e2","client_comm_id":"8f94627395a14583a7b6b676495266aa"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"95c15ce8-c450-48a3-9d4d-34c884ac8f27","roots":{"730f3d7d-796c-4947-9c58-860e15985a19":"d6abacaa-bd2a-441f-8380-72fabb18d7bf"},"root_ids":["730f3d7d-796c-4947-9c58-860e15985a19"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.21.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.8.0">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>

# %%
# Set up default plot dimensions for better viewing of large graphs
defaults = dict(width=1200, height=800)
hv.opts.defaults(
    opts.EdgePaths(**defaults), opts.Graph(**defaults), opts.Nodes(**defaults)
)

# %% [markdown]
# ## Configuration
#
# Set up MongoDB connection and LLM for entity extraction.

# %%
CONNECTION_STRING = os.environ.get("MONGODB_URI", "")
DB_NAME = "langchain_test_db"
COLLECTION_NAME = "langchain_graphrag_large_example"

# Configure the LLM for entity extraction
# Using gpt-4o for high-quality entity extraction
entity_extraction_model = ChatOpenAI(
    model="gpt-4o", temperature=0.0, cache=False, seed=12345
)

# %% [markdown]
# ## Load and Chunk Text Data
#
# Load the large text dataset and split it into paragraph-sized chunks.

# %%
# Load the text data
data_file = Path("../tests/integration_tests/data/large_graph_dataset.txt")
text_content = data_file.read_text()

print(f"Loaded text file with {len(text_content)} characters")
print(f"Preview:\n{text_content[:300]}...")
# Out:
# Loaded text file with 13764 characters
# Preview:
# TechVision 2024 Global Conference Opens in Austin
#
# Austin, TX — The TechVision 2024 Global Conference kicked off on March 15th at the Austin Convention Center, drawing over 5,000 attendees from around the world. The conference, organized by Global Tech Events Inc., focuses on emerging technologies i...

# %%
# Split text into chunks using RecursiveCharacterTextSplitter
# This creates natural document boundaries at paragraph breaks
text_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", " ", ""],
    chunk_size=1000,
    chunk_overlap=100,
    length_function=len,
)

text_chunks = text_splitter.split_text(text_content)
print(f"Split text into {len(text_chunks)} chunks")

# Convert to Document objects
documents = [Document(page_content=chunk) for chunk in text_chunks]
print(f"Created {len(documents)} Document objects")
# Out:
# Split text into 20 chunks
# Created 20 Document objects

# %% [markdown]
# ## Build Knowledge Graph
#
# Create `MongoDBGraphStore` and extract entities from the documents.
#
# **Note:** This step takes several minutes as the LLM processes each chunk to extract entities and relationships.

# %%
# Create the graph store
graph_store = MongoDBGraphStore(
    connection_string=CONNECTION_STRING,
    database_name=DB_NAME,
    collection_name=COLLECTION_NAME,
    entity_extraction_model=entity_extraction_model,
    max_depth=3,  # Allow deeper graph traversal for complex queries
)

print(f"Created MongoDBGraphStore connected to {DB_NAME}.{COLLECTION_NAME}")
# Out:
# Created MongoDBGraphStore connected to langchain_test_db.langchain_graphrag_large_example

# %%
# Extract entities from documents
# This may take 1-2 minutes depending on the number of chunks and LLM response time
print(f"Processing {len(documents)} documents...")
bulkwrite_results = graph_store.add_documents(documents)

print(f"Processed {len(bulkwrite_results)} document chunks")
print("Entity extraction complete!")
# Out:
# Processing 20 documents...
# Targets, types, and attributes do not have the same length for TechVision 2024 Global Conference!
# Targets, types, and attributes do not have the same length for Quantum Dynamics Corp!
# Targets, types, and attributes do not have the same length for TechVision Conference!
# Targets, types, and attributes do not have the same length for AI Ethics Initiative!
# Targets, types, and attributes do not have the same length for Green Computing Alliance!
# Targets, types, and attributes do not have the same length for James Wilson!
# Targets, types, and attributes do not have the same length for Carbon Zero Data Center Project!
# Targets, types, and attributes do not have the same length for SolarTech Industries!
# Targets, types, and attributes do not have the same length for Marcus Brown!
# Targets, types, and attributes do not have the same length for Blockchain Healthcare Consortium!
# Targets, types, and attributes do not have the same length for Blockchain Healthcare Consortium!
# Targets, types, and attributes do not have the same length for MediChain Solutions!
# Targets, types, and attributes do not have the same length for HealthSecure Systems!
# Targets, types, and attributes do not have the same length for PatientFirst Technologies!
# Targets, types, and attributes do not have the same length for CareConnect Networks!
# Targets, types, and attributes do not have the same length for VitalData Corp!
# Targets, types, and attributes do not have the same length for Dr. Amanda Foster!
# Targets, types, and attributes do not have the same length for Dr. Thomas Anderson!
# Targets, types, and attributes do not have the same length for SkyLink Project!
# Targets, types, and attributes do not have the same length for Rachel Martinez!
# Targets, types, and attributes do not have the same length for Cybersecurity Summit!
# Targets, types, and attributes do not have the same length for SecureNet Solutions!
# Targets, types, and attributes do not have the same length for CryptoGuard Technologies!
# Targets, types, and attributes do not have the same length for Dr. Kevin O'Brien!
# Targets, types, and attributes do not have the same length for Professor Alice Thompson!
# Targets, types, and attributes do not have the same length for Dr. Yuki Tanaka!
# Targets, types, and attributes do not have the same length for QuantumShield!
# Targets, types, and attributes do not have the same length for BioTech Innovations!
# Targets, types, and attributes do not have the same length for Dr. Maria Santos!
# Targets, types, and attributes do not have the same length for Dr. James Patterson!
# Targets, types, and attributes do not have the same length for Genomics Research Center!
# Targets, types, and attributes do not have the same length for Molecular Computing Corp!
# Targets, types, and attributes do not have the same length for Oncology Research Institute!
# Targets, types, and attributes do not have the same length for Memorial Medical Center!
# Targets, types, and attributes do not have the same length for TechVision 2024!
# Targets, types, and attributes do not have the same length for Smart Cities Initiative!
# Targets, types, and attributes do not have the same length for Carlos Rodriguez!
# Targets, types, and attributes do not have the same length for Patricia Williams!
# Targets, types, and attributes do not have the same length for Renewable Energy Tech Summit!
# Targets, types, and attributes do not have the same length for SunPower Innovations!
# Targets, types, and attributes do not have the same length for Advanced Solar Materials!
# Targets, types, and attributes do not have the same length for Global Energy Solutions!
# Targets, types, and attributes do not have the same length for EduVerse Technologies!
# Targets, types, and attributes do not have the same length for Dr. Christopher Lee!
# Targets, types, and attributes do not have the same length for Digital Learning Alliance!
# Targets, types, and attributes do not have the same length for Interactive Education Systems!
# Targets, types, and attributes do not have the same length for Global School Network!
# Targets, types, and attributes do not have the same length for Educational Content Creators Guild!
# Targets, types, and attributes do not have the same length for International Education Standards Board!
# Targets, types, and attributes do not have the same length for Samantha Brown!
# Targets, types, and attributes do not have the same length for Autonomous Vehicle Consortium!
# Targets, types, and attributes do not have the same length for Self-Drive Motors!
# Targets, types, and attributes do not have the same length for Open Banking Coalition!
# Targets, types, and attributes do not have the same length for Digital Payments Corp!
# Targets, types, and attributes do not have the same length for Mobile Banking Solutions!
# Targets, types, and attributes do not have the same length for Investment Tech Group!
# Targets, types, and attributes do not have the same length for InsureTech Innovations!
# Targets, types, and attributes do not have the same length for LendingTree Technologies!
# Targets, types, and attributes do not have the same length for Michael Zhang!
# Targets, types, and attributes do not have the same length for Federal Banking Regulators!
# Targets, types, and attributes do not have the same length for Financial Security Council!
# Targets, types, and attributes do not have the same length for International Banking Standards Organization!
# Targets, types, and attributes do not have the same length for API Standards Institute!
# Targets, types, and attributes do not have the same length for Financial Data Alliance!
# Targets, types, and attributes do not have the same length for Ocean Monitoring Network!
# Targets, types, and attributes do not have the same length for Marine Research Institute!
# Targets, types, and attributes do not have the same length for EdgeCloud Technologies!
# Targets, types, and attributes do not have the same length for Brian Murphy!
# Targets, types, and attributes do not have the same length for Dr. Susan Park!
# Targets, types, and attributes do not have the same length for TranslateTech Global!
# Targets, types, and attributes do not have the same length for NanoMed Devices!
# Targets, types, and attributes do not have the same length for Fusion Dynamics Corporation!
# Processed 20 document chunks
# Entity extraction complete!

# %% [markdown]
# ## Graph Statistics
#
# Examine the extracted knowledge graph.

# %%
# Count entities
entity_count = graph_store.collection.count_documents({})
print(f"Total entities extracted: {entity_count}")

# Get all entities
entities = list(graph_store.collection.find({}))

# Analyze entity types
entity_types = {}
for entity in entities:
    entity_type = entity.get("type", "Unknown")
    entity_types[entity_type] = entity_types.get(entity_type, 0) + 1

print("\nEntity types:")
for entity_type, count in sorted(
    entity_types.items(), key=lambda x: x[1], reverse=True
):
    print(f"  {entity_type}: {count}")

# Analyze relationships
entities_with_relationships = [
    entity for entity in entities if entity.get("relationships", {}).get("target_ids")
]

total_relationships = sum(
    len(entity.get("relationships", {}).get("target_ids", []))
    for entity in entities_with_relationships
)

print("\nRelationships:")
print(f"  Entities with relationships: {len(entities_with_relationships)}")
print(f"  Total relationship edges: {total_relationships}")
print(
    f"  Average relationships per connected entity: {total_relationships / len(entities_with_relationships):.1f}"
)
# Out:
# Total entities extracted: 181
#
# Entity types:
#   Organization: 126
#   Person: 36
#   Event: 6
#   Location: 5
#   Product: 3
#   Project: 3
#   Technology: 1
#   Concept: 1
#
# Relationships:
#   Entities with relationships: 84
#   Total relationship edges: 212
#   Average relationships per connected entity: 2.5

# %% [markdown]
# ## Sample Entities
#
# Display a few example entities from the graph.

# %%
# Show some sample entities with relationships
print("Sample entities with relationships:\n")
for i, entity in enumerate(entities_with_relationships[:5]):
    print(f"{i+1}. {entity['_id']} ({entity.get('type')})")
    relationships = entity.get("relationships", {})
    target_ids = relationships.get("target_ids", [])
    rel_types = relationships.get("types", [])
    print(f"   Relationships: {len(target_ids)}")
    for target, rel_type in zip(target_ids[:3], rel_types[:3]):
        print(f"     - {rel_type} -> {target}")
    if len(target_ids) > 3:
        print(f"     ... and {len(target_ids) - 3} more")
    print()

# %% [markdown]
# ## Query the Knowledge Graph
#
# Test querying the graph to find related entities.

# %%
# Example query about relationships
query = (
    "What is the connection between Quantum Dynamics Corp and NanoTech Materials Ltd?"
)

# Extract entity names from query
entity_names = graph_store.extract_entity_names(query)
print(f"Extracted entities from query: {entity_names}")

# Find related entities through graph traversal
if entity_names:
    related_entities = graph_store.related_entities(entity_names)
    print(f"\nFound {len(related_entities)} related entities:")
    for entity in related_entities[:10]:
        print(f"  - {entity['_id']} ({entity.get('type')})")
    if len(related_entities) > 10:
        print(f"  ... and {len(related_entities) - 10} more")
# Out:
# Extracted entities from query: ['Quantum Dynamics Corp', 'NanoTech Materials Ltd']
#
# Found 5 related entities:
#   - Quantum Processor (Technology)
#   - Dr. Michael Torres (Person)
#   - Quantum Dynamics Corp (Organization)
#   - NanoTech Materials Ltd. (Organization)
#   - QX-7000 (Product)

# %%
# Get a natural language response using the knowledge graph
answer = graph_store.chat_response(query)
print(f"Chat Response:\n{answer.content}")
# Out:
# Chat Response:
# Quantum Dynamics Corp and NanoTech Materials Ltd. are connected through a partnership, with NanoTech Materials Ltd. providing superconducting materials to Quantum Dynamics Corp.

# %% [markdown]
# ## Visualize Knowledge Graph
#
# Create interactive visualizations of the knowledge graph using HoloViews and NetworkX.
#
# ### Basic Graph View
#
# First, we'll create a basic visualization of the entire graph.

# %%
# Create basic view of the entire graph
basic_view = graph_store.view()
basic_view
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4db25c08-2b02-417e-ba27-4ee587a2d24c'>
#   <div id="d5a7ab77-8a9c-4f18-bf2a-b46fac0ff7c1" data-root-id="4db25c08-2b02-417e-ba27-4ee587a2d24c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4ef48faf-bec9-464e-ae95-16b11b2e6eb1":{"version":"3.8.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"69d02ad7-1178-4eaf-a96b-d52ed88cc873","attributes":{"notifications":{"type":"object","name":"Notifications","id":"b211f64b-344e-41eb-9b3c-e0a0105652a0"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4db25c08-2b02-417e-ba27-4ee587a2d24c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d4ba8ec7-7d58-45b5-bd0c-cadda9b1e019","attributes":{"plot_id":"4db25c08-2b02-417e-ba27-4ee587a2d24c","comm_id":"b8f0b382506a46b4806adcb59cb20136","client_comm_id":"b7ad9b36857343ec9926bd5c85f60063"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"4ef48faf-bec9-464e-ae95-16b11b2e6eb1","roots":{"4db25c08-2b02-417e-ba27-4ee587a2d24c":"d5a7ab77-8a9c-4f18-bf2a-b46fac0ff7c1"},"root_ids":["4db25c08-2b02-417e-ba27-4ee587a2d24c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.21.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.8.0">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# :Overlay
#    .Graph.I :Graph   [start,end]   (attributes,type)
#    .Nodes.I :Nodes   [x,y,index]   (attributes,type)

# %% [markdown]
# ### NetworkX Graph Layouts
#
# Convert to NetworkX for advanced layout algorithms and analytics.

# %%
# Convert to NetworkX graph
nx_graph = graph_store.to_networkx()

print(
    f"NetworkX graph: {nx_graph.number_of_nodes()} nodes, {nx_graph.number_of_edges()} edges"
)
print(f"Graph density: {nx.density(nx_graph):.4f}")

# Check if graph is connected
if nx_graph.number_of_nodes() > 0:
    is_connected = nx.is_connected(nx_graph.to_undirected())
    print(f"Is connected: {is_connected}")

    if not is_connected:
        components = list(nx.connected_components(nx_graph.to_undirected()))
        print(f"Number of connected components: {len(components)}")
        print(f"Largest component size: {len(max(components, key=len))}")
# Out:
# NetworkX graph: 181 nodes, 212 edges
# Graph density: 0.0065
# Is connected: False
# Number of connected components: 23
# Largest component size: 16

# %% [markdown]
# ### Multipartite Layout (by Entity Type)
#
# Visualize the graph with entities grouped by type.

# %%
# Create multipartite layout grouping entities by type
by_type = hv.Graph.from_networkx(nx_graph, nx.multipartite_layout, subset_key="type")
type_view = by_type.opts(
    inspection_policy="edges",
    tools=["hover", "tap"],
    node_color="type",
    cmap="Category20",
    node_size=10,
    edge_line_width=1,
    edge_alpha=0.5,
) * by_type.nodes.opts(
    size=10,
    color="type",
    cmap="Category20",
    alpha=0.8,
)

type_view
# Out:
# :Overlay
#    .Graph.I :Graph   [start,end]   (attributes,type)
#    .Nodes.I :Nodes   [x,y,index]   (attributes,type)

# %% [markdown]
# ### Spring Layout
#
# Use a force-directed layout for organic graph visualization.

# %%
# Create spring layout (force-directed)
spring_layout = hv.Graph.from_networkx(nx_graph, nx.spring_layout, k=0.5, iterations=50)
spring_view = spring_layout.opts(
    inspection_policy="edges",
    tools=["hover", "tap"],
    node_color="type",
    cmap="Category20",
    node_size=10,
    edge_line_width=1,
    edge_alpha=0.4,
) * spring_layout.nodes.opts(
    size=10,
    color="type",
    cmap="Category20",
    alpha=0.8,
)

spring_view
# Out:
# :Overlay
#    .Graph.I :Graph   [start,end]   (attributes,type)
#    .Nodes.I :Nodes   [x,y,index]   (attributes,type)

# %% [markdown]
# ### Focused Subgraph Visualization
#
# Visualize a subgraph around specific entities for detailed exploration.

# %%
# Pick an entity with many connections
if entities_with_relationships:
    # Find entity with most relationships
    most_connected = max(
        entities_with_relationships,
        key=lambda e: len(e.get("relationships", {}).get("target_ids", [])),
    )

    print(
        f"Most connected entity: {most_connected['_id']} ({most_connected.get('type')})"
    )
    print(
        f"Number of relationships: {len(most_connected.get('relationships', {}).get('target_ids', []))}"
    )

    # Get subgraph around this entity
    focus_entity = most_connected["_id"]
    related = graph_store.related_entities([focus_entity], max_depth=2)

    print(f"\nSubgraph contains {len(related)} entities")

    # Create a subgraph from these entities
    subgraph_nodes = {entity["_id"] for entity in related}
    subgraph = nx_graph.subgraph(subgraph_nodes).copy()

    print(
        f"Subgraph: {subgraph.number_of_nodes()} nodes, {subgraph.number_of_edges()} edges"
    )

    # Visualize subgraph
    if subgraph.number_of_nodes() > 0:
        sub_spring = hv.Graph.from_networkx(
            subgraph, nx.spring_layout, k=0.8, iterations=50
        )
        subgraph_view = sub_spring.opts(
            inspection_policy="edges",
            tools=["hover", "tap"],
            node_color="type",
            cmap="Category20",
            node_size=15,
            edge_line_width=2,
            edge_alpha=0.6,
            title=f"Subgraph around {focus_entity}",
        ) * sub_spring.nodes.opts(
            size=15,
            color="type",
            cmap="Category20",
            alpha=0.9,
        )

# Display the subgraph view
subgraph_view  # noqa: F821

# %% [markdown]
# ## Export Visualizations
#
# Save the visualizations as HTML files for sharing.

# %%
# Save visualizations
hv.save(type_view, "graph_by_type.html")
print("Saved graph_by_type.html")

hv.save(spring_view, "graph_spring.html")
print("Saved graph_spring.html")

print("\nVisualizations exported successfully!")

# %% [markdown]
# ## Summary
#
# In this notebook, we:
#
# 1. ✅ Loaded a large text corpus with ~100 entities
# 2. ✅ Chunked text into documents using `RecursiveCharacterTextSplitter`
# 3. ✅ Built a knowledge graph using `MongoDBGraphStore` and LLM-based entity extraction
# 4. ✅ Analyzed graph statistics (entities, types, relationships)
# 5. ✅ Queried the graph for related entities and chat responses
# 6. ✅ Visualized the graph using multiple layout algorithms
# 7. ✅ Explored focused subgraphs around highly-connected entities
# 8. ✅ Exported interactive visualizations as HTML
#
# The resulting knowledge graph can be used for:
# - Complex multi-hop queries
# - Entity relationship discovery
# - Context-aware chat responses
# - Graph analytics and network analysis
